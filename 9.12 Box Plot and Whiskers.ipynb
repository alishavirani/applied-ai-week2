# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

iris = pd.read_csv("Iris.csv")

# %%
#Histogram does not give info on the Percentiles and Quartiles and IQR
#Histograms are good to know the density
#However CDFs can be used to know the percentile values, by looking at the y-axis to know the percentage and x-axis to know the value
#Box-Plot helps visualizing the percentiles

# %%
#Box-plot with whiskers: another method of visualizing the  1-D scatter plot more intuitively.
# The Concept of median, percentile, quantile.
# How to draw the box in the box-plot?
# How to draw whiskers: [no standard way] Could use min and max or use other complex statistical techniques.
# IQR like idea.

#Refer Image 1, the values 25,50,75 correspond to percentile values
#NOTE: IN the plot below, a technique call inter-quartile range is used in plotting the whiskers. 
#Whiskers in the plot below donot correposnd to the min and max values.

#Box-plot can be visualized as a PDF on the side-ways.

#The width of box plot has no significance

sns.boxplot(x='Species',y='PetalLengthCm', data=iris)
plt.grid()
plt.show()

# %%
#suppose we set a threshold of 5 for Versicolor and Virginica
if PL > 2 and PL < 5:
    flower = "Versicolor"
if PL >=5:
    flower = "Virginica" # 25 % error
#5 is roughly where the value of Virginica is 25percentile
#ie there are 25% virginica whose PL < 5, therefore 25% error

#the lines are called whiskers
#no std way of drawing whiskers
# One way of drawing is the min and max value at the start and end of the box-plot
#Seaborn uses a different way to draw whiskers
#It takes 1.5 * IQR (most of the points will lie)
#IQR is the width of the box plot ie 75th percentile - 25th percentile - where 50% of the points lie
#refer image 2
